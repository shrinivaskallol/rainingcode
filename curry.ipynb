# %%
import json
from watson_developer_cloud import ConversationV1
import speech_recognition as sr
conversation = ConversationV1(
  username = '23964d72-883b-4c47-883b-e38f89cf42ed',
  password = 'jGw78Ugxd7yk',
  version = '2017-05-26'
)

# Replace with the context obtained from the initial request
context = {}

workspace_id = '116a1c26-6236-478b-acde-a7175ca01811'

#def main():
    #while True:
       # prompt_user()
        
 
  
     
#def prompt_user():

def main():
    while True:
        prompt_user()
        
    

def prompt_user():


         # get audio from the microphone                                                                       
    r = sr.Recognizer()                                                                                   
    with sr.Microphone() as source:                                                                       
        print("Speak:")                                                                                   
        audio = r.listen(source)   

    try:
        print("You said :" + r.recognize_google(audio))
    except sr.UnknownValueError:
        print("Could not understand audio")
    except sr.RequestError as e:
        print("Could not request results; {0}".format(e)) 

    a = r.recognize_google(audio) 






    response = conversation.message(
        workspace_id = workspace_id,
      message_input = {'text':  a },
      context = context
            )

    json.dumps(response, indent=2)
            #aa=json.dumps(response, indent=2)

    q = (response['output']['text'])
            #cityy =response['entities'][0]['value']
    print(q)
    
    
        
    
    


if __name__ == '__main__': main()
# Out:
# Speak:
# You said :what do you have in solids
# []
# Speak:
# You said :what do you have in Spanish
# []
# Speak:
# You said :what are you having salad
# ["Hi I'm SpeakEat. I can help you with ordering your food, customizing it and even paying your bills!"]
# Speak:
# You said :okay
# []
# Speak:
# You said :bye
# ["Have a nice meal! I'll be around in case you need anything!"]
# Speak:
# You said :what do you have in salads
# []
# Speak:
# You said :what do you have in pictures
# []
# Speak:
# You said :what do you have in pizzas
# ['We have pizza with the following toppings: Cheese, Salami and Veggies. And we have it in various sizes: Pan, Small, medium, large and extra large']
# Speak:
# You said :what do you have in salad
# []
# Speak:
# You said :what do you have in ice creams
# ['We have vanilla, strawberry and chocolate ice creams. You can order single or double scoop']
# Speak:
# You said :what do you have in calories
# []
# Speak:
# You said :what do you have encouraged
# []
# ...

# %%
import json
from watson_developer_cloud import ConversationV1
import speech_recognition as sr
conversation = ConversationV1(
  username = '23964d72-883b-4c47-883b-e38f89cf42ed',
  password = 'jGw78Ugxd7yk',
  version = '2017-05-26'
)

# Replace with the context obtained from the initial request
context = {}

workspace_id = '116a1c26-6236-478b-acde-a7175ca01811'

#def main():
    #while True:
       # prompt_user()
        
def man():
     pass
#def prompt_user():
while True:
    try:


        def main():
            while True:
                prompt_user()



        def prompt_user():


                 # get audio from the microphone                                                                       
            r = sr.Recognizer()                                                                                   
            with sr.Microphone() as source:                                                                       
                print("SpeakEAT:")                                                                                   
                audio = r.listen(source)   

            try:
                print("You said :" + r.recognize_google(audio))
            except sr.UnknownValueError:
                print("I am sorry, I Could not understand you")
            except sr.RequestError as e:
                print("Could not request results; {0}".format(e)) 

            a = r.recognize_google(audio)
            
        
            

            




            response = conversation.message(
                workspace_id = workspace_id,
              message_input = {'text':  a },
              context = context
                    )

            json.dumps(response, indent=2)
                    #aa=json.dumps(response, indent=2)

            q = (response['output']['text'])
                    #cityy =response['entities'][0]['value']
            print(q)
            
            if 'end' in 
            
           



        



        if __name__ == '__main__': main()
            
    
            
                     
     
    except:
        print('sdsd')
        pass
# Out:
# SpeakEAT:
# I am sorry, I Could not understand you
# sdsd
# SpeakEAT:
# You said :hello
# ["Hi I'm SpeakEat. I can help you with ordering your food, customizing it and even paying your bills!"]
# SpeakEAT:
# You said :I want to order food
# ['This is a bla bla bla restaurant which serves blank cuisine mainly. We have starter salads, pizza, bread, gravy, curries and icecreams']
# SpeakEAT:
# You said :options entry jobs
# ["Have a nice meal! I'll be around in case you need anything!"]
# SpeakEAT:
# You said :goodbye
# ["Have a nice meal! I'll be around in case you need anything!"]
# SpeakEAT:
# I am sorry, I Could not understand you
# sdsd
# SpeakEAT:
# I am sorry, I Could not understand you
# sdsd
# SpeakEAT:
# I am sorry, I Could not understand you

# %%
import json
from watson_developer_cloud import ConversationV1
import speech_recognition as sr
conversation = ConversationV1(
  username = '58b9c259-61ca-4f04-94c8-33977d4cbc4a',
  password = 'iGwqoXlyi0yl',
  version = '2017-05-26'
)

# Replace with the context obtained from the initial request
context = {}

workspace_id = '4772f2dd-a711-4a7b-98f0-05b26a35bd5a'

from watson_developer_cloud import NaturalLanguageUnderstandingV1
import watson_developer_cloud.natural_language_understanding.features.v1 as \
    Features

#def main():
    #while True:
       # prompt_user()
        
  
  
     
#def prompt_user():

#def man():
     #pass
#def prompt_user():
def main():


        
        while True:
            try:
            #while True:
                #prompt_user()



        #def prompt_user():


                     # get audio from the microphone                                                                       
                r = sr.Recognizer()                                                                                   
                with sr.Microphone() as source:                                                                       
                    print("SpeakEaT:")                                                                                   
                    audio = r.listen(source)   

                try:
                    print("You said :" + r.recognize_google(audio))
                except sr.UnknownValueError:
                    print("....")
                except sr.RequestError as e:
                    print("Could not request results; {0}".format(e)) 

                a = r.recognize_google(audio) 








                response = conversation.message(
                    workspace_id = workspace_id,
                  message_input = {'text':  a },
                  context = context
                        )

                json.dumps(response, indent=2)
                        #aa=json.dumps(response, indent=2)

                q = (response['output']['text'])
                        #cityy =response['entities'][0]['value']
                print(q)
                
                c = ['get me', 'add', 'i want', 'i will take', 'i will have']
                
                
                if 'get me' in a:
                    natural_language_understanding = NaturalLanguageUnderstandingV1(
                    version='2017-02-27',
                    username='64a41724-ef1f-4599-820a-4f4c00ea7fc6',
                    password='5WCU7pWGJbCt')

                    responsee = natural_language_understanding.analyze(
                    text= a,
                    features=[Features.Entities(model='10:5381961b-3e95-429d-87e6-64a25dc59222'), Features.Keywords()])

                    jfile = (json.dumps(responsee, indent=2))

                    qty = responsee['entities'][0]['text']
                    item =responsee['entities'][1]['text']
                    
                    order = item
                    prices = {'chicken biryani' : 12 , 'lamb biryani' :15 , 'chicken chili': 7 , 'chicken kabab':7, 'chicken chinatown' : 9, 'Veggie mix': 10, 
                              'medium veggie salad': 11, 'veg biryani': 10, 'butter chicken': 12, 'pepper chicken' :10, 'spinach curry': 10, 'lamb Curry':15,
                               'spicy red hot Curry': 10, 'chicken Tandoori': 20, 'lamb roast' : 18, 'Indian Chicken Roast' : 20,
                              'mango lassi':4, 'plain lassi': 2, 'sweet lime soda': 5, 'soda': 2, 'carrot pudding':5, 'sugary rounds':5,
                             'cashew roll': 7, 'cashew sandwich': 10, 'roti':1, 'Paratha': 2, 'rotis': 1}
                    wq= prices.get(order)
                    wq = float(wq)
                    num_dict = {'one':1,'a':1, 'two' : 2, 'three': 3, 'four': 4, 'five':5, 'six' : 6, 'seven': 7, 7:7}
                    qtyfloat = num_dict.get(qty)
                    amt = wq * qtyfloat
                    
                    
                    record = "conforming ->> {} {} ------   $ {}".format(qty,order, amt)
                    
                    print(record)
                    
                   
                    
                    
                    
                    
                    
                    #print("conforming ->> {} {} ------   $ {}".format(qty,order, amt))
                    
                        

                    
                    
                    
                    if 'biryani' in a:
                        print('\nI would suggest you to add a soda with the biryani and/or cilantro chutney\n')
                        
                    
                    if 'butter chicken' in a:
                        print('\n I strongly recommend having the curry with our breads, please ask me about our breads\n')
                        
                    if 'chicken Tandoori' in a:
                        print('\n I suggest adding sweet lime soda or mango lassi to couter the hotness\n')
                
                
                
                        
                    
                    
                

                if  'menu' in a:
                    print('''
                    
                    INDIAN CURRY HOUSE
                    -------------------------------------------------------------------------------------------------
                    APPETIZERS or QUICK BITES:
                      
                    * Chicken Chili:                                                                          --> $ 7
                    Indian Chilli Chicken is a south east Asian twist as batter friend chicken is smothered    
                    in garlic, soy sauce and chilli gravy. Try real Indian Chinese food!
                    
                    * Chicken Kabab:
                    Tender flavorful and aromatic grilled chicken kabab.                                      --> $ 7
                    
                     
                    * Chicken Chinatown: Spicy pair of chicken legs with spicy red sauce                      --> $ 10
                    
                    * Veggie mix:(contains no meat)
                    Fresh vegetables marinated with corn bater and grilled to perfection
                    served with soy sauce                                                                     --> $ 10
                    
                    --------------------------------------------------------------------------------------------------
                    
                    BIRYANI: 
                    
                    Steamed rice made with a whole lot of spices and love, served with your favourite meat
                    
                    * Chicken Biryani:                                                                         --> $ 12
                    
                    * Lamb Biryani:                                                                            --> $ 15
                    
                    * Veg Biryani(contains no meat):                                                           --> $ 10
                    
                    ---------------------------------------------------------------------------------------------------
                    
                    CURRY:
                    
                    Sauce made out of yogart, onions, whole spices, served with your favourite meat or
                    your favourite vegitables 
                    
                    * Butter Chicken:                                                                          --> $ 12
                    
                    * Pepper Chicken:                                                                          --> $ 10
                    
                    * Spinach Curry:                                                                           --> $ 10
                    
                    * Spicy red hot curry(contains no meat):                                                   --> $ 10
                    
                    * Lamb Curry:                                                                              --> $ 15
                    
                    ----------------------------------------------------------------------------------------------------
                    
                    BREADS:
                    
                    * Roti:                                                                                    --> $ 1
                    
                    * Paratha:                                                                                 --> $ 2
                    
                    -----------------------------------------------------------------------------------------------------
                   
                    SPECIAL:
                    
                    * Chicken Tandoori(Full chicken):                                                          --> $ 20
                    
                    * Lamb Roast:                                                                              --> $ 18
                    
                    * Indian Chicken Roast:                                                                    --> $ 20
                    
                    -----------------------------------------------------------------------------------------------------
                    
                    
                    DRINKS:
                    
                    * Mango Lassi:                                                                              --> $ 4
                    
                    * Plain Lassi:                                                                              --> $ 2
                    
                    * Sweet lime soda:                                                                          --> $ 5
                    
                    * Pop/Soda:                                                                                 --> $ 2
                    
                    -----------------------------------------------------------------------------------------------------
                    
                    DESSERTS:
                    
                    * Carrot Pudding:                                                                            --> $ 5
                    
                    * Sugary rounds:                                                                             --> $ 5
                    
                    * Cashew rolls:                                                                              --> $ 7
                    
                    * Cashew sandwich:                                                                           --> $ 10
                    
                    ------------------------------------------------------------------------------------------------------
                    ''')
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    

                
                if 'break' in a:
                    print('Thank u, come again')
                    break


            
            except:
                pass
                
                

                



if __name__ == '__main__': main()
# Out:
# SpeakEaT:
# You said :hello
# ["Hello. I am Speakeat, I can help you make the best choice from all that we have to offer. I can recommend food if its your first time here. I can help you customize your dish and help you checkout. Please feel free to inquire about any of our dishes I'll roll out the details for you:)"]
# SpeakEaT:
# You said :help me order food
# ["You can filter the menu in the following ways: JUST SAY 1) Hot and Spicy OR medium spicy   2)Chicken items OR Lamb items OR veg items  3) Most popular items    4) Display full menu 5) Quick bite OR main course                                                                                                  \n ## I can help you get the details on all of our dishes, just ask What is 'DISH NAME' ##"]
# SpeakEaT:
# You said :hot and spicy food
# ['We have pepper chicken, Red hot curry, chicken tandoori which are too hot to handle. I can also help you add spice to any of the dishes.']
# SpeakEaT:
# You said :so I'm coming over
# ...

# %%
import ipywidgets as widgets

# %%
widgets.IntSlider(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)

# %%
play = widgets.Play(
#     interval=10,
    value=50,
    min=0,
    max=100,
    step=1,
    description="Press play",
    disabled=False
)
slider = widgets.IntSlider()
widgets.jslink((play, 'value'), (slider, 'value'))
widgets.HBox([play, slider])

# %%
widgets.Button(
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check'
)

# %%
widgets.HTMLMath(
    value=r"Some math and <i>HTML</i>: \(x^2\) and $$\frac{x+1}{x-1}$$",
    placeholder='Some HTML',
    description='Some HTML',
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4191c50c1147> in <module>()
# ----> 1 widgets.HTMLMath(
#       2     value=r"Some math and <i>HTML</i>: \(x^2\) and $$\frac{x+1}{x-1}$$",
#       3     placeholder='Some HTML',
#       4     description='Some HTML',
#       5 )
#
# AttributeError: module 'ipywidgets' has no attribute 'HTMLMath'
